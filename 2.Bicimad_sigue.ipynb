# %%
#Import libraries, read merged file as list of dictionaries 
import os
os.chdir(r'C:\Users\Usuario\Documents\Daniela Arias\Tesis\Practical\Comparativo\Pre-covid\Bicimad')
import json

# %%
with open('final.json', 'r') as data:
    for i in data:
        i = json.loads(i)

# %%
len(i)
# Out:
# 4571038

# %%
type(i)
# Out:
# list

# %%
i
# Out:
# [{'travel_time': 162,
#   'idunplug_station': 82,
#   'idplug_station': 83,
#   'user_type': 1,
#   'fecha': '2019-01-01T00'},
#  {'travel_time': 415,
#   'idunplug_station': 133,
#   'idplug_station': 36,
#   'user_type': 1,
#   'fecha': '2019-01-01T00'},
#  {'travel_time': 545,
#   'idunplug_station': 25,
#   'idplug_station': 90,
#   'user_type': 1,
#   'fecha': '2019-01-01T00'},
#  {'travel_time': 417,
#   'idunplug_station': 105,
#   'idplug_station': 155,
#   'user_type': 1,
#   'fecha': '2019-01-01T00'},
#  {'travel_time': 448,
#   'idunplug_station': 51,
#   'idplug_station': 44,
#   'user_type': 1,
#   'fecha': '2019-01-01T00'},
#  {'travel_time': 639,
#   'idunplug_station': 44,
#   'idplug_station': 125,
#   'user_type': 1,
#   'fecha': '2019-01-01T00'},
#  {'travel_time': 362,
#   'idunplug_station': 17,
#   'idplug_station': 11,
#   'user_type': 1,
#   'fecha': '2019-01-01T00'},
#  {'travel_time': 468,
#   'idunplug_station': 100,
#   'idplug_station': 171,
# ...

# %%
# Create new properties with timestamp
for dic in i: 
    dic['year']= dic['fecha'][:4]
    dic['month']= dic['fecha'][5:7]
    dic['day']= dic['fecha'][8:10]
    dic['hour']= dic['fecha'][11:13]

# %%
i
# Out:
# [{'travel_time': 162,
#   'idunplug_station': 82,
#   'idplug_station': 83,
#   'user_type': 1,
#   'fecha': '2019-01-01T00',
#   'year': '2019',
#   'month': '01',
#   'day': '01',
#   'hour': '00'},
#  {'travel_time': 415,
#   'idunplug_station': 133,
#   'idplug_station': 36,
#   'user_type': 1,
#   'fecha': '2019-01-01T00',
#   'year': '2019',
#   'month': '01',
#   'day': '01',
#   'hour': '00'},
#  {'travel_time': 545,
#   'idunplug_station': 25,
#   'idplug_station': 90,
#   'user_type': 1,
#   'fecha': '2019-01-01T00',
#   'year': '2019',
#   'month': '01',
#   'day': '01',
#   'hour': '00'},
#  {'travel_time': 417,
#   'idunplug_station': 105,
#   'idplug_station': 155,
#   'user_type': 1,
#   'fecha': '2019-01-01T00',
#   'year': '2019',
#   'month': '01',
#   'day': '01',
#   'hour': '00'},
#  {'travel_time': 448,
#   'idunplug_station': 51,
#   'idplug_station': 44,
#   'user_type': 1,
#   'fecha': '2019-01-01T00',
#   'year': '2019',
#   'month': '01',
#   'day': '01',
# ...

# %%
#We need to delete user_type=3 as they are Bicimad workers trips 

#we count user_type=3 
sum(x.get('user_type') == 3 for x in i)
# Out:
# 309772

# %%
#we delete the 309772 trips

defi = [u for u in i if not (u['user_type'] == 3)]

# %%
len(defi)
# Out:
# 4261266

# %%
#save defi
with open(r'C:\Users\Usuario\Documents\Daniela Arias\Tesis\Practical\Comparativo\Pre-covid\Bicimad\final_final.json', 'w') as alfa: 
    alfa.write(json.dumps(defi) + "\n")
